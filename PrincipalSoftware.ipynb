# %%
# Proyecto Principalsoftware  (Puntoycoma)
# Tendencias e Innovación en Tecnología Agrícola
# Escuela Agrícola Panamerica Zamorano

# %%
import pandas as pd

# %%
Tea =pd.read_csv("Tea.csv")

# %%
Tea
# Out:
#             Months  Years     Data
# 0    PrepPromAnual   2015    41.00
# 1    PrepPromAnual   2016   681.80
# 2    PrepPromAnual   2017   929.60
# 3    PrepPromAnual   2018   872.00
# 4    PrepPromAnual   2019  1106.00
# 5    PrepPromAnual   2020   882.18
# 6    PrepPromAnual   2021   794.20
# 7    PrepPromAnual   2022   176.60
# 8    TMaxPromAnual   2015    33.10
# 9    TMaxPromAnual   2016    37.30
# 10   TMaxPromAnual   2017    35.70
# 11   TMaxPromAnual   2018    34.20
# 12   TMaxPromAnual   2019    44.30
# 13   TMaxPromAnual   2020    42.10
# 14   TMaxPromAnual   2021    44.10
# 15   TMaxPromAnual   2022    56.90
# 16   TMinPromAnual   2015    13.70
# 17   TMinPromAnual   2016   -67.80
# 18   TMinPromAnual   2017     6.20
# 19   TMinPromAnual   2018     2.00
# 20   TMinPromAnual   2019   -20.60
# 21   TMinPromAnual   2020   -67.80
# 22   TMinPromAnual   2021     8.30
# 23   TMinPromAnual   2022     7.90
# 24      TPromAnual   2015    22.38
# 25      TPromAnual   2016    23.13
# ...

# %%
precipitacion=  Tea[Tea.Months == "PrepPromAnual"]

# %%
precipitacion
# Out:
#           Months  Years     Data
# 0  PrepPromAnual   2015    41.00
# 1  PrepPromAnual   2016   681.80
# 2  PrepPromAnual   2017   929.60
# 3  PrepPromAnual   2018   872.00
# 4  PrepPromAnual   2019  1106.00
# 5  PrepPromAnual   2020   882.18
# 6  PrepPromAnual   2021   794.20
# 7  PrepPromAnual   2022   176.60

# %%
from matplotlib import pyplot as plt

# %%
plt.plot (precipitacion.Years, precipitacion.Data,color="teal", linewidth=3, linestyle="-")
plt.xlabel("Año",color= "black",fontsize= 13)
plt.ylabel("Dato",color= "black",fontsize= 13)
plt.title("Precipitación Promedio Anual de Zamorano 2015-2022",fontsize= 12,color= "maroon")
plt.show()

# %%
tempmax=  Tea[Tea.Months == "TMaxPromAnual"]

# %%
tempmax
# Out:
#            Months  Years  Data
# 8   TMaxPromAnual   2015  33.1
# 9   TMaxPromAnual   2016  37.3
# 10  TMaxPromAnual   2017  35.7
# 11  TMaxPromAnual   2018  34.2
# 12  TMaxPromAnual   2019  44.3
# 13  TMaxPromAnual   2020  42.1
# 14  TMaxPromAnual   2021  44.1
# 15  TMaxPromAnual   2022  56.9

# %%
plt.plot (tempmax.Years, tempmax.Data,color="orange", linewidth=3, linestyle="-")
plt.xlabel("Año",color= "black",fontsize= 13)
plt.ylabel("Dato",color= "black",fontsize= 13)
plt.title("Temp Máxima Promedio Anual de Zamorano 2015-2022",fontsize= 12,color= "maroon")
plt.show()

# %%
tempmin=  Tea[Tea.Months == "TMinPromAnual"]

# %%
tempmin
# Out:
#            Months  Years  Data
# 16  TMinPromAnual   2015  13.7
# 17  TMinPromAnual   2016 -67.8
# 18  TMinPromAnual   2017   6.2
# 19  TMinPromAnual   2018   2.0
# 20  TMinPromAnual   2019 -20.6
# 21  TMinPromAnual   2020 -67.8
# 22  TMinPromAnual   2021   8.3
# 23  TMinPromAnual   2022   7.9

# %%
plt.plot (tempmin.Years, tempmin.Data,color="turquoise", linewidth=3, linestyle="-")
plt.xlabel("Año",color= "black",fontsize= 13)
plt.ylabel("Dato",color= "black",fontsize= 13)
plt.title("Temp Mínima Promedio Anual de Zamorano 2015-2022",fontsize= 12,color= "maroon")
plt.show()

# %%
Tempprom=  Tea[Tea.Months == "TPromAnual"]

# %%
Tempprom
# Out:
#         Months  Years   Data
# 24  TPromAnual   2015  22.38
# 25  TPromAnual   2016  23.13
# 26  TPromAnual   2017  22.29
# 27  TPromAnual   2018  22.82
# 28  TPromAnual   2019  23.45
# 29  TPromAnual   2020  22.96
# 30  TPromAnual   2021  23.13
# 31  TPromAnual   2022  23.36

# %%
plt.plot (Tempprom.Years, Tempprom.Data,color="fuchsia", linewidth=3, linestyle="-")
plt.xlabel("Año",color= "black",fontsize= 13)
plt.ylabel("Dato",color= "black",fontsize= 13)
plt.title("Temp Promedio Anual de Zamorano 2015-2022",fontsize= 12,color= "maroon")
plt.show()

# %%
hrelativa=  Tea[Tea.Months == "HrelaPromAnual"]

# %%
hrelativa
# Out:
#             Months  Years   Data
# 32  HrelaPromAnual   2015  79.29
# 33  HrelaPromAnual   2016  76.12
# 34  HrelaPromAnual   2017  76.11
# 35  HrelaPromAnual   2018  75.42
# 36  HrelaPromAnual   2019  74.88
# 37  HrelaPromAnual   2020  82.87
# 38  HrelaPromAnual   2021  76.24
# 39  HrelaPromAnual   2022  68.55

# %%
plt.plot (hrelativa.Years, hrelativa.Data,color="yellow", linewidth=3, linestyle="-")
plt.xlabel("Año",color= "black",fontsize= 13)
plt.ylabel("Dato",color= "black",fontsize= 13)
plt.title("Humedad relativa Promedio Anual de Zamorano 2015-2022",fontsize= 12,color= "maroon")
plt.show()

# %%
# Comparación de la Temperatura Máxima y Mínima de Zamorano 2015-2022

# %%
Temmax= Tea [Tea.Months == "TMaxPromAnual"]
Temmix= Tea [Tea.Months == "TMinPromAnual"]

# %%
plt.plot (Temmax.Years, Temmax.Data,color="green", linewidth=5, linestyle="-")
plt.plot (Temmix.Years, Temmix.Data,color="red", linewidth=5, linestyle="-")
plt.xlabel ("Año",color= "black",fontsize= 13 )
plt.ylabel ("Promedio",color= "black",fontsize= 13)
plt.title("Comparación de la TempMax y TempMin de Zamorano",fontsize= 12,color= "red")
plt.legend (["TMaxPromAnual", "TMinPromAnual"])
plt.show()
